# %% [markdown]
# <a href="https://colab.research.google.com/github/jakeRyan11/MachineLearningIsFun/blob/main/CreditCardFraudDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing libraries

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#loading dataset to Pandas datframe
credit_card_data=pd.read_csv('/content/fraudTest.csv')

# %%
#first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
credit_card_data.drop(columns=('Unnamed: 0'),inplace=True)

# %%
credit_card_data['trans_date_trans_time'] = pd.to_datetime(credit_card_data['trans_date_trans_time'])
credit_card_data['dob'] = pd.to_datetime(credit_card_data['dob'])
credit_card_data['unix_time'] = pd.to_datetime(credit_card_data['unix_time'], unit='s')

# %%
credit_card_data.tail()
# Out:
#         Unnamed: 0 trans_date_trans_time               cc_num  \
# 147548      147548   2020-08-11 13:43:41      377993105397617
# 147549      147549   2020-08-11 13:43:52      213157767990030
# 147550      147550   2020-08-11 13:44:13     4449530933957323
# 147551      147551   2020-08-11 13:44:26        4681699462969
# 147552      147552   2020-08-11 13:44:32  4742883543039288059
#
#                             merchant   category     amt      first      last  \
# 147548  fraud_Cole, Hills and Jewess       home  128.64     Nathan  Martinez
# 147549   fraud_Breitenberg-Hermiston  kids_pets   14.18       Tara  Campbell
# 147550             fraud_Streich Ltd       home   81.54    Felicia     Mckee
# 147551         fraud_Lubowitz-Walter  kids_pets   63.38     Joseph  Gonzalez
# 147552              fraud_Herzog Ltd   misc_pos    7.16  Cassandra   Sanders
#
#        gender                      street  ...      lat      long  city_pop  \
# ...

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147553 entries, 0 to 147552
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   trans_date_trans_time  147553 non-null  datetime64[ns]
#  1   cc_num                 147553 non-null  int64
#  2   merchant               147553 non-null  object
#  3   category               147553 non-null  object
#  4   amt                    147553 non-null  float64
#  5   first                  147553 non-null  object
#  6   last                   147553 non-null  object
#  7   gender                 147553 non-null  object
#  8   street                 147553 non-null  object
#  9   city                   147553 non-null  object
#  10  state                  147553 non-null  object
#  11  zip                    147553 non-null  int64
#  12  lat                    147553 non-null  float64
#  13  long                   147552 non-null  float64
# ...

# %%
#checking the number of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     1
# city_pop                 1
# job                      1
# dob                      1
# trans_num                1
# unix_time                1
# merch_lat                1
# merch_long               1
# is_fraud                 1
# dtype: int64

# %%
#distribution of legit and fraudulent transactions

credit_card_data['category'].value_counts()
# Out:
# category
# gas_transport     15212
# grocery_pos       13970
# home              13697
# shopping_pos      13097
# kids_pets         12901
# shopping_net      11201
# food_dining       10657
# entertainment     10548
# personal_care     10420
# health_fitness     9724
# misc_pos           9173
# misc_net           7239
# grocery_net        5063
# travel             4651
# Name: count, dtype: int64

# %% [markdown]
# 0-->Normal Transaction
# 1--->Fraudulent Transaction

# %% [markdown]
# This dataset is highly unbalanced

# %%
legit = credit_card_data[credit_card_data.is_fraud==0]
fraud = credit_card_data[credit_card_data.is_fraud==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (146911, 22)
# (641, 22)

# %% [markdown]
# #statistical measures of data

# %%
legit.amt.describe()
# Out:
# count    146911.000000
# mean         67.714314
# std         147.575258
# min           1.000000
# 25%           9.630000
# 50%          47.290000
# 75%          82.660000
# max       13149.150000
# Name: amt, dtype: float64

# %%
fraud.amt.describe()
# Out:
# count     641.000000
# mean      492.192605
# std       392.305872
# min         4.640000
# 25%        95.520000
# 50%       341.910000
# 75%       882.130000
# max      1267.180000
# Name: amt, dtype: float64

# %% [markdown]
# Under-sampling

# %% [markdown]
# Build a sample dataset containing similar dataset of normal transaction and the fraudulent transaction

# %% [markdown]
# Number of fraudulent transactions---> 641

# %%
legit_sample = legit.sample(n=641)

# %% [markdown]
# Concatenate two datframes

# %%
new_dataset = pd.concat([legit_sample,fraud],axis=0)

# %%
new_dataset.head()
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 119095      119095   2020-08-02 07:50:11      573283817795
# 21381        21381   2020-06-28 20:18:37     4642894980163
# 7367          7367   2020-06-23 09:56:03  3549202406645667
# 36134        36134   2020-07-03 23:13:01  6597888193422452
# 17966        17966   2020-06-27 18:23:18  4277232699798846
#
#                                  merchant       category    amt     first  \
# 119095  fraud_Schaefer, McGlynn and Bosco  gas_transport  61.33       Amy
# 21381              fraud_Balistreri-Nader       misc_pos  13.52     Eddie
# 7367                    fraud_Larson-Moen  entertainment   6.55     Larry
# 36134                   fraud_Waelchi Inc      kids_pets   2.89      Bill
# 17966                    fraud_Bednar Inc         travel   3.66  Jennifer
#
#             last gender                     street  ...      lat      long  \
# 119095     Flynn      F           46095 Tara Fords  ...  42.8178  -72.0275
# ...

# %%
new_dataset['is_fraud'].value_counts()
# Out:
# is_fraud
# 0.0    641
# 1.0    641
# Name: count, dtype: int64

# %%
X = new_dataset.drop(columns='is_fraud', axis=1)
Y = new_dataset['is_fraud']

# %%
print(X)
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 119095      119095   2020-08-02 07:50:11      573283817795
# 21381        21381   2020-06-28 20:18:37     4642894980163
# 7367          7367   2020-06-23 09:56:03  3549202406645667
# 36134        36134   2020-07-03 23:13:01  6597888193422452
# 17966        17966   2020-06-27 18:23:18  4277232699798846
# ...            ...                   ...               ...
# 146034      146034   2020-08-11 02:56:25    30238755902988
# 146158      146158   2020-08-11 03:48:12  4335531783520911
# 146170      146170   2020-08-11 03:53:44  4335531783520911
# 146491      146491   2020-08-11 06:18:38    30238755902988
# 147273      147273   2020-08-11 12:11:13  2284059275940012
#
#                                    merchant       category      amt     first  \
# 119095    fraud_Schaefer, McGlynn and Bosco  gas_transport    61.33       Amy
# 21381                fraud_Balistreri-Nader       misc_pos    13.52     Eddie
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (1282, 22) (1025, 22) (257, 22)

# %% [markdown]
# Model Training
#
# Logistic Regression

# %%
categorical_cols = [col for col in X_train.columns if X_train[col].dtype == 'object']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoders = {}

# %%
for col in categorical_cols:
    le = LabelEncoder()

    # Fit on combined data (train + test) to maintain consistency
    combined_data = pd.concat([X_train[col], X_test[col]], axis=0).astype(str)
    le.fit(combined_data)

    # Transform train and test sets
    X_train[col] = le.transform(X_train[col].astype(str))
    X_test[col] = le.transform(X_test[col].astype(str))

    # Store the encoder for future use
    label_encoders[col] = le

# %%
model = LogisticRegression()

# %%
# training the Logistic Regression Model with Training Data
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
print(model)
# Out:
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.5004878048780488

# %%
 #accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.4980544747081712
